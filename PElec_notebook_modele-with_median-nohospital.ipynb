# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model, preprocessing, metrics
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVR
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from lightgbm import LGBMRegressor
import time

# %%
df = pd.read_csv('df_for_model.csv')
df = df.drop('Unnamed: 0',axis=1)

# %%
SiteEnergyUse_discrete = pd.qcut(df['SiteEnergyUse(kBtu)'],3, labels = False)
GHGEmission_discrete = pd.qcut(df['GHGEmissions(MetricTonsCO2e)'],3, labels = False)
df.insert(11, 'SiteEnergyUse_discrete', SiteEnergyUse_discrete)
df.insert(12, 'GHGEmission_discrete', GHGEmission_discrete)

# %%
df['SiteEnergyUse(kBtu)_log'] = np.log1p(df['SiteEnergyUse(kBtu)'])
df['GHGEmissions(MetricTonsCO2e)_log'] = np.log1p(df['GHGEmissions(MetricTonsCO2e)'])

# %%
df=df.drop(df[df['PrimaryPropertyType']=='Hospital'].index)

# %%
df.columns
# Out:
# Index(['PrimaryPropertyType', 'Neighborhood', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFAParking', 'PropertyGFABuilding(s)',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'ENERGYSTARScore', 'SiteEnergyUse(kBtu)', 'SiteEnergyUse_discrete',
#        'GHGEmission_discrete', 'GHGEmissions(MetricTonsCO2e)',
#        'MedianEnergyUse', 'MedianGHGEmission', 'SiteEnergyUse(kBtu)_log',
#        'GHGEmissions(MetricTonsCO2e)_log'],
#       dtype='object')

# %%
data=df['Neighborhood'].values.reshape(-1,1)
enc = preprocessing.OneHotEncoder()
neighborhood_enc = enc.fit_transform(data).toarray()
neighborhood_enc.shape
# Out:
# (1800, 13)

# %%
data=df['PrimaryPropertyType'].values.reshape(-1,1)
enc = preprocessing.OneHotEncoder()
PropertyType_enc = enc.fit_transform(data).toarray()
PropertyType_enc.shape
# Out:
# (1800, 24)

# %%
X_cat = np.concatenate((neighborhood_enc,PropertyType_enc),axis=1)
X_cat.shape
# Out:
# (1800, 37)

# %%
#X_cat = np.concatenate((X_cat,df['SiteEnergyUse_discrete'].to_numpy().reshape(-1,1)),axis=1)

# %%
X_quant = df[['YearBuilt', 'NumberofBuildings', 'NumberofFloors', 'PropertyGFABuilding(s)','MedianEnergyUse','MedianGHGEmission']]
X_quant.values.shape
# Out:
# (1800, 6)

# %%
X_cat.shape
# Out:
# (1800, 37)

# %%
Y_energy_log = df['SiteEnergyUse(kBtu)_log']
Y_ghg_log = df['GHGEmissions(MetricTonsCO2e)_log']
Y_energy_bis = df['SiteEnergyUse(kBtu)']
Y_ghg_bis = df['GHGEmissions(MetricTonsCO2e)']

# %%
X_cat_train, X_cat_test, X_quant_train, X_quant_test, Y_energy_log_train, Y_energy_log_test, Y_ghg_log_train, Y_ghg_log_test, Y_energy_bis_train, Y_energy_bis_test, Y_ghg_bis_train, Y_ghg_bis_test = train_test_split(X_cat, X_quant, Y_energy_log, Y_ghg_log, Y_energy_bis, Y_ghg_bis, test_size=0.3, stratify = df['PrimaryPropertyType'], random_state = 1)

# %%
std = preprocessing.StandardScaler()
X_quant_train_scaled = std.fit_transform(X_quant_train)
X_quant_test_scaled = std.transform(X_quant_test)

# %%
X_train = np.concatenate((X_cat_train,X_quant_train_scaled),axis=1)
X_test = np.concatenate((X_cat_test,X_quant_test_scaled),axis=1)

# %%
# Régression linéaire sur cibles en log
lr_energy = linear_model.LinearRegression()
lr_energy.fit(X_train,Y_energy_log_train)

print('R² test sur variable log:', round(metrics.r2_score(Y_energy_log_test,lr_energy.predict(X_test)),3))
print('R² test sur variable origine:', round(metrics.r2_score(np.expm1(Y_energy_log_test),np.expm1(lr_energy.predict(X_test))),3))

print('R² train sur variable log:',round(metrics.r2_score(Y_energy_log_train,lr_energy.predict(X_train)),3))
print('R² train sur variable orig:',round(metrics.r2_score(np.expm1(Y_energy_log_train),np.expm1(lr_energy.predict(X_train))),3))
# Out:
# R² test sur variable log: 0.459
# R² test sur variable origine: -0.058
# R² train sur variable log: 0.53
# R² train sur variable orig: -26.235

# %%
# Régression linéaire sur cibles non transformées
lr_energy_bis = linear_model.LinearRegression()
lr_energy_bis.fit(X_train,Y_energy_bis_train)

print('R² test :', round(metrics.r2_score(Y_energy_bis_test,lr_energy_bis.predict(X_test)),3))
print('R² train :',round(metrics.r2_score(Y_energy_bis_train,lr_energy_bis.predict(X_train)),3))
# Out:
# R² test : 0.504
# R² train : 0.747

# %%
recap_energy = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for energy')
recap_ghg = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for GHG')

# %%
recap_energy_log = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for energy log')
recap_ghg_log = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for GHG log')

# %%
def perf(X_train,Y_train,X_test,Y_test,model,hyperparam):
    
    '''Fonction permettant la recherche des meilleurs hyperparamètres d'un modèle puis 
    l'entrainement de ce modèle avec ces meilleurs paramètres sur le jeu X_train, Y_train
    La fonction retourne les performances du modèle (R², RMSE, temps d'éxécution) et les meilleurs paramètres
    
    le paramètre 'hyperparam' de la fonction est un dictionnaire
    
    Liste des hyperparamètres selon certains modèles :
    - Régression linéaire : pas d'hyperparamètre
    - Régression Ridge : alpha
    - Regression Lasso : alpha
    - Elasticnet : alpha et l1_ratio
    - SVR : estimator__C, estimator__epsilon et estimator__kernel
    - Random Forest : 
    '''
        
    model_gs = GridSearchCV(estimator = model, param_grid=hyperparam, cv=5)      
        
    model_gs.fit(X_train, Y_train)
    start_time = time.time()
    score = round(metrics.r2_score(Y_test,model_gs.predict(X_test)),5)     
    RMSE = round(metrics.mean_squared_error(Y_test,model_gs.predict(X_test), squared = False),5)
    pred_time = round(time.time()-start_time, 6)
    best_param = model_gs.best_params_
    for k, v in best_param.items():
        if type(v)!= str :
            best_param[k] = round(v, 6)
   
    return score, RMSE, pred_time, best_param



def recap_table(X_train,Y_energy_train,Y_ghg_train,X_test,Y_energy_test,Y_ghg_test,model,hyperparam):
    score, RMSE, pred_time, best_param = perf(X_train,Y_energy_train,X_test,Y_energy_test,model,hyperparam)
    recap_energy.loc[str(model),:] = [score,RMSE,pred_time,best_param]
    
    score, RMSE, pred_time, best_param = perf(X_train,Y_ghg_train,X_test,Y_ghg_test,model,hyperparam)
    recap_ghg.loc[str(model),:] = [score,RMSE,pred_time,best_param]

# %%
def perf_log(X_train,Y_train,X_test,Y_test,model,hyperparam):
    
    '''Fonction permettant la recherche des meilleurs hyperparamètres d'un modèle puis 
    l'entrainement de ce modèle avec ces meilleurs paramètres sur le jeu X_train, Y_train
    La fonction retourne les performances du modèle (R², RMSE, temps d'éxécution) et les meilleurs paramètres
    
    le paramètre 'hyperparam' de la fonction est un dictionnaire
    
    Liste des hyperparamètres selon certains modèles :
    - Régression linéaire : pas d'hyperparamètre
    - Régression Ridge : alpha
    - Regression Lasso : alpha
    - Elasticnet : alpha et l1_ratio
    - SVR : estimator__C, estimator__epsilon et estimator__kernel
    - Random Forest : 
    '''
        
    model_gs = GridSearchCV(estimator = model, param_grid=hyperparam, cv=5)      
        
    model_gs.fit(X_train, Y_train)
    start_time = time.time()
    score = round(metrics.r2_score(np.expm1(Y_test),np.expm1(model_gs.predict(X_test))),5)     
    RMSE = round(metrics.mean_squared_error(np.expm1(Y_test),np.expm1(model_gs.predict(X_test)), squared = False),5)
    pred_time = round(time.time()-start_time, 6)
    best_param = model_gs.best_params_
    for k, v in best_param.items():
        if type(v)!= str :
            best_param[k] = round(v, 6)
   
    return score,RMSE, pred_time, best_param



def recap_table_log(X_train,Y_energy_train,Y_ghg_train,X_test,Y_energy_test,Y_ghg_test,model,hyperparam):
    score, RMSE, pred_time, best_param = perf_log(X_train,Y_energy_train,X_test,Y_energy_test,model,hyperparam)
    recap_energy_log.loc[str(model),:] = [score,RMSE,pred_time,best_param]
    
    score, RMSE, pred_time, best_param = perf_log(X_train,Y_ghg_train,X_test,Y_ghg_test,model,hyperparam)
    recap_ghg_log.loc[str(model),:] = [score,RMSE,pred_time,best_param]

# %%
LinearReg = linear_model.LinearRegression();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,LinearReg,{})

# %%
ridge = Ridge();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,ridge,{'alpha': np.logspace(-4,2,100)})

# %%
lasso = Lasso();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,lasso,{'alpha': np.logspace(-4,2,100)})
# Out:
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130914657618e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356072320163e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721111070916906e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795821412834e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591549955717e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565129092786022e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.267235664134452e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721114855185744e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409796310017739e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928592864788478e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565128385671361e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672354978968e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721112561195906e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795418703522e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928589932156118e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565131677787436e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356390208322e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.272111203559121e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409796789959003e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591241493707e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565128908965941e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356684041066e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721112358062163e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.40979563303877e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928592975879186e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.5651307730004296e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672357836245056e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721112147653283e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.40979621212337e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.192859161256113e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565129680233786e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672355332294456e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113503987125e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409796824211128e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.192859311180668e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565129227802098e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356319011378e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113536658262e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795467902608e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591460453803e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565129914845533e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.267235648492178e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721112904315416e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795845808181e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591773915274e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565131269722213e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672355882335005e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113026282242e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409796437646576e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591109974901e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565129755340038e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.267235664840541e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721112415756083e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409796124296237e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.192859080099907e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.5651305070105224e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356843284189e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113348279067e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.40979568281547e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591403879734e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130099382723e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672357041966448e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113439407064e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795975652928e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591249895875e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.56513059304232e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.267235655510808e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113307348262e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795685582869e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591327008795e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130398782909e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356685932835e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113175875499e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795862136107e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591321880774e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.5651306075694136e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356422984672e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113099399347e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795618342029e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591807895258e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130264720113e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356691652365e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.272111308651968e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409796015400448e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591320203597e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130605358024e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356547771603e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113105585446e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795728978878e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591528914554e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.5651305195772216e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.267235663304175e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113122006816e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795769343182e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591409305614e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130526668161e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356878068299e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.272111303868573e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.4097958756555e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591538458435e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130443376045e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356693255426e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113129408656e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795909180114e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591467451075e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130453371125e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356910361328e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113301999891e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795809043853e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591481476805e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130529767774e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.26723568215878e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113184224478e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795954761824e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591349142723e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.56513044130247e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356854111992e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113249474512e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795897638654e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591562006962e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130475554187e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356809116667e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113275037245e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795984366597e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591515011454e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.56513044264377e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356870590507e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113267885211e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.40979598649832e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591503480125e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130563558274e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356911594632e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113286398448e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409795952397163e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.19285915688201e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130578435063e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356871800642e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113326241797e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409796066240922e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591562282563e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130666127786e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356881869456e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.272111335057784e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409796035761574e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591509052702e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130696174482e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356959338624e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113349124938e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409796023820458e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.192859153755065e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130719353204e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672356957289552e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113422931682e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.409796081811222e+16, tolerance: 109095116971661.02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1928591589552269e+17, tolerance: 43579875922335.4
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.565130713391068e+16, tolerance: 96520725261772.31
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2672357005678467e+17, tolerance: 117614868306021.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2721113447702426e+17, tolerance: 118656246327521.9
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16221685.347488414, tolerance: 21374.803431519955
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99039950.57494667, tolerance: 50156.96649715427
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89241853.50593477, tolerance: 50852.19251220275
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57104421.35525642, tolerance: 47696.084859765004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82157053.82119685, tolerance: 38643.86797239674
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16046224.836433962, tolerance: 21374.803431519955
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99042863.38729522, tolerance: 50156.96649715427
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89244687.71867965, tolerance: 50852.19251220275
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57106578.7930956, tolerance: 47696.084859765004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82159566.9366484, tolerance: 38643.86797239674
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15886345.750400176, tolerance: 21374.803431519955
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24064856.553376466, tolerance: 50156.96649715427
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89247899.69445123, tolerance: 50852.19251220275
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57109042.69240455, tolerance: 47696.084859765004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82162403.25492652, tolerance: 38643.86797239674
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15813020.010776833, tolerance: 21374.803431519955
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10251482.652829409, tolerance: 50156.96649715427
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89251499.55876498, tolerance: 50852.19251220275
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57111847.29284789, tolerance: 47696.084859765004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82165593.97861162, tolerance: 38643.86797239674
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7002640.980359014, tolerance: 21374.803431519955
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10245027.773968875, tolerance: 50156.96649715427
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89255515.17752025, tolerance: 50852.19251220275
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54735272.410480976, tolerance: 47696.084859765004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82169169.46237195, tolerance: 38643.86797239674
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10246738.090197861, tolerance: 50156.96649715427
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10760816.164079309, tolerance: 50852.19251220275
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52778032.61112645, tolerance: 47696.084859765004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5965610.672546595, tolerance: 38643.86797239674
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10248699.67980194, tolerance: 50156.96649715427
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10038479.011951774, tolerance: 50852.19251220275
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52764164.354091704, tolerance: 47696.084859765004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 74475.51125568151, tolerance: 38643.86797239674
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10250929.871624053, tolerance: 50156.96649715427
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10037933.247716278, tolerance: 50852.19251220275
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52768317.066257715, tolerance: 47696.084859765004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10253461.012847811, tolerance: 50156.96649715427
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10040380.051854163, tolerance: 50852.19251220275
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48636545.320301965, tolerance: 47696.084859765004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10256327.190471947, tolerance: 50156.96649715427
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10043175.400124878, tolerance: 50852.19251220275
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18023343.591386378, tolerance: 47696.084859765004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10259564.748150796, tolerance: 50156.96649715427
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10046334.35951674, tolerance: 50852.19251220275
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5538397.31923601, tolerance: 47696.084859765004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 334141.9918704033, tolerance: 50156.96649715427
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10049892.99951616, tolerance: 50852.19251220275
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1692298.5914601684, tolerance: 47696.084859765004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10053887.231897384, tolerance: 50852.19251220275
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 557369.532074213, tolerance: 47696.084859765004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10058340.383313566, tolerance: 50852.19251220275
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 206092.5726981759, tolerance: 47696.084859765004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85660.95885950327, tolerance: 47696.084859765004
#   model = cd_fast.enet_coordinate_descent(

# %%
svr = SVR(kernel = 'linear');
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,svr,{'C' : range(1,5),
                                       'epsilon' : np.linspace(0.1,1,10)})

# %%
svr = SVR();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,svr,{'C' : range(1,5),
                                        'epsilon' : np.linspace(0.1,1,10), 
                                       'kernel' : ['rbf','poly','sigmoid']})

# %%
rfr = RandomForestRegressor();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test, rfr, {'min_samples_split' : [2, 5, 10], 
                                             'min_samples_leaf' : [1, 2, 4], 
                                             'max_depth': range(5,16,1)})

# %%
gb = LGBMRegressor();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test, gb, {'n_estimators': [10, 50, 100, 150, 200],'max_depth':range(5,16, 2), 
                                                                                                     'learning_rate' : [0.0001,0.001,0.01,0.1,1], 
                                                                                                     'boosting_type' : ['gbdt','goss', 'dart'], 'num_leaves':[30]})

# %%
recap_energy
# Out:
#                               R²         RMSE Prediction time  \
# Model for energy
# LinearRegression()       0.50444  8.47627e+06        0.002003
# Ridge()                  0.54737  8.10077e+06           0.001
# Lasso()                  0.50398  8.48014e+06           0.003
# SVR(kernel='linear')    -0.11398  1.27085e+07        0.060004
# SVR()                   -0.11395  1.27083e+07        0.071016
# RandomForestRegressor()  0.64467  7.17749e+06         0.06585
# LGBMRegressor()          0.61273  7.49315e+06        0.005001
#
#                                                            Best parameters
# Model for energy
# LinearRegression()                                                      {}
# Ridge()                                               {'alpha': 37.649358}
# Lasso()                                                   {'alpha': 100.0}
# SVR(kernel='linear')                              {'C': 4, 'epsilon': 0.1}
# SVR()                           {'C': 4, 'epsilon': 0.2, 'kernel': 'poly'}
# RandomForestRegressor()  {'max_depth': 15, 'min_samples_leaf': 1, 'min_...
# LGBMRegressor()          {'boosting_type': 'dart', 'learning_rate': 0.1...

# %%
recap_ghg
# Out:
#                               R²     RMSE Prediction time  \
# Model for GHG
# LinearRegression()       0.20214  302.982        0.002002
# Ridge()                  0.27485  288.846        0.001999
# Lasso()                  0.22335  298.926           0.002
# SVR(kernel='linear')     0.22879  297.879        0.067004
# SVR()                    0.06649  327.727        0.094025
# RandomForestRegressor()   0.3468  274.142        0.031998
# LGBMRegressor()          0.47112  246.678           0.004
#
#                                                            Best parameters
# Model for GHG
# LinearRegression()                                                      {}
# Ridge()                                                   {'alpha': 100.0}
# Lasso()                                               {'alpha': 10.722672}
# SVR(kernel='linear')                              {'C': 4, 'epsilon': 1.0}
# SVR()                        {'C': 4, 'epsilon': 0.3, 'kernel': 'sigmoid'}
# RandomForestRegressor()  {'max_depth': 9, 'min_samples_leaf': 2, 'min_s...
# LGBMRegressor()          {'boosting_type': 'goss', 'learning_rate': 0.1...

# %%
LinearReg = linear_model.LinearRegression();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,LinearReg,{})

# %%
ridge = Ridge();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,ridge,{'alpha': np.logspace(-4,2,100)})

# %%
lasso = Lasso();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,lasso,{'alpha': np.logspace(-4,2,100)})
# Out:
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.053272056397532, tolerance: 0.17517760807167526
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.072883710915107, tolerance: 0.17517760807167526
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.094872008344282, tolerance: 0.17517760807167526
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.119397548709799, tolerance: 0.17517760807167526
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.146625636098065, tolerance: 0.17517760807167526
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.5379101054741113, tolerance: 0.17517760807167526
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6623383507600238, tolerance: 0.17517760807167526
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.31409508931869823, tolerance: 0.17517760807167526
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 185.3189485540256, tolerance: 0.2098895700617248
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81.87715421001735, tolerance: 0.2123016365984499
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137.70171342037463, tolerance: 0.20849336905682578
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.214790144065773, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102.86839173602243, tolerance: 0.2098895700617248
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77.81297864640078, tolerance: 0.2123016365984499
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137.60884609481946, tolerance: 0.20849336905682578
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.279229088610009, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97.24159305180751, tolerance: 0.2098895700617248
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77.88701527879198, tolerance: 0.2123016365984499
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137.72203138916325, tolerance: 0.20849336905682578
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.935323371405275, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97.34766104962353, tolerance: 0.2098895700617248
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77.97106653867388, tolerance: 0.2123016365984499
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137.84669582315746, tolerance: 0.20849336905682578
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.118575368589745, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97.46687483810217, tolerance: 0.2098895700617248
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78.06515946730246, tolerance: 0.2123016365984499
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137.98279423432575, tolerance: 0.20849336905682578
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.688363087957441, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70.08638981291222, tolerance: 0.2098895700617248
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78.16999345833335, tolerance: 0.2123016365984499
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138.12969547287832, tolerance: 0.20849336905682578
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.552006007157843, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54.65049622791696, tolerance: 0.2098895700617248
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78.28602374314607, tolerance: 0.2123016365984499
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138.28593849197978, tolerance: 0.20849336905682578
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.640498477106576, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78.4134608715093, tolerance: 0.2123016365984499
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136.77426504556206, tolerance: 0.20849336905682578
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.895850771239338, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.2781867005355707, tolerance: 0.2123016365984499
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 121.5539726422578, tolerance: 0.20849336905682578
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.29332091980541, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.64587409464423, tolerance: 0.20849336905682578
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.80454121891762, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3054610778667666, tolerance: 0.20849336905682578
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.4083379823191535, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.065746254159649, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.714789481416119, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.3800036599950545, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9799194411052667, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6497382521454256, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23383905050468456, tolerance: 0.2048109716316301
#   model = cd_fast.enet_coordinate_descent(

# %%
svr = SVR(kernel = 'linear');
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,svr,{'C' : range(1,5),
                                       'epsilon' : np.linspace(0.1,1,10)})

# %%
svr = SVR();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,svr,{'C' : range(1,5),
                                        'epsilon' : np.linspace(0.1,1,10), 
                                       'kernel' : ['rbf','poly','sigmoid']})

# %%
rfr = RandomForestRegressor();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test, rfr, {'min_samples_split' : [2, 5, 10], 
                                             'min_samples_leaf' : [1, 2, 4], 
                                             'max_depth': range(5,16,1)})

# %%
gb = LGBMRegressor();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test, gb, {'n_estimators': [150],'max_depth': [5], 
                                                                                                     'learning_rate' : [0.09], 
                                                                                                     'boosting_type' : ['gbdt'], 'num_leaves':[30]})

# %%
recap_energy_log
# Out:
#                               R²         RMSE Prediction time  \
# Model for energy log
# LinearRegression()      -0.05824  1.23864e+07        0.001999
# Ridge()                  0.17253  1.09529e+07           0.001
# Lasso()                   -0.063  1.24143e+07        0.002001
# SVR(kernel='linear')    -0.00913  1.20956e+07        0.019001
# SVR()                     0.5693  7.90208e+06        0.078005
# RandomForestRegressor()  0.60955  7.52384e+06        0.039003
# LGBMRegressor()          0.67291  6.88639e+06        0.012001
#
#                                                            Best parameters
# Model for energy log
# LinearRegression()                                                      {}
# Ridge()                                                   {'alpha': 100.0}
# Lasso()                                                  {'alpha': 0.0001}
# SVR(kernel='linear')                              {'C': 4, 'epsilon': 0.8}
# SVR()                            {'C': 4, 'epsilon': 0.1, 'kernel': 'rbf'}
# RandomForestRegressor()  {'max_depth': 12, 'min_samples_leaf': 1, 'min_...
# LGBMRegressor()          {'boosting_type': 'gbdt', 'learning_rate': 0.0...

# %%
recap_ghg_log
# Out:
#                               R²     RMSE Prediction time  \
# Model for GHG log
# LinearRegression()      -0.00772  340.503           0.002
# Ridge()                  0.03878  332.555           0.002
# Lasso()                  0.03786  332.714           0.002
# SVR(kernel='linear')     -0.0164  341.967        0.034007
# SVR()                    0.25289  293.187        0.050004
# RandomForestRegressor()  0.41471    259.5        0.039002
# LGBMRegressor()          0.52091   234.78        0.015001
#
#                                                            Best parameters
# Model for GHG log
# LinearRegression()                                                      {}
# Ridge()                                                   {'alpha': 100.0}
# Lasso()                                                {'alpha': 0.215443}
# SVR(kernel='linear')                              {'C': 2, 'epsilon': 1.0}
# SVR()                            {'C': 3, 'epsilon': 0.6, 'kernel': 'rbf'}
# RandomForestRegressor()  {'max_depth': 13, 'min_samples_leaf': 1, 'min_...
# LGBMRegressor()          {'boosting_type': 'gbdt', 'learning_rate': 0.0...

# %%
recap_energy_log.iloc[-1,-1]
# Out:
# {'boosting_type': 'gbdt',
#  'learning_rate': 0.09,
#  'max_depth': 5,
#  'n_estimators': 150,
#  'num_leaves': 30}
