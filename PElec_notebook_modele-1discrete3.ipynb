# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model, preprocessing, metrics
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVR
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from lightgbm import LGBMRegressor
import time

# %%
df = pd.read_csv('df_for_model.csv')
df = df.drop('Unnamed: 0',axis=1)

# %%
SiteEnergyUse_discrete = pd.qcut(df['SiteEnergyUse(kBtu)'],3, labels = False)
GHGEmission_discrete = pd.qcut(df['GHGEmissions(MetricTonsCO2e)'],3, labels = False)
df.insert(11, 'SiteEnergyUse_discrete', SiteEnergyUse_discrete)
df.insert(12, 'GHGEmission_discrete', GHGEmission_discrete)

# %%
df['SiteEnergyUse(kBtu)_log'] = np.log1p(df['SiteEnergyUse(kBtu)'])
df['GHGEmissions(MetricTonsCO2e)_log'] = np.log1p(df['GHGEmissions(MetricTonsCO2e)'])

# %%
df.columns
# Out:
# Index(['PrimaryPropertyType', 'Neighborhood', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFAParking', 'PropertyGFABuilding(s)',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'ENERGYSTARScore', 'SiteEnergyUse(kBtu)', 'SiteEnergyUse_discrete',
#        'GHGEmission_discrete', 'GHGEmissions(MetricTonsCO2e)',
#        'MedianEnergyUse', 'SiteEnergyUse(kBtu)_log',
#        'GHGEmissions(MetricTonsCO2e)_log'],
#       dtype='object')

# %%
data=df['Neighborhood'].values.reshape(-1,1)
enc = preprocessing.OneHotEncoder()
neighborhood_enc = enc.fit_transform(data).toarray()
neighborhood_enc.shape
# Out:
# (1811, 13)

# %%
data=df['PrimaryPropertyType'].values.reshape(-1,1)
enc = preprocessing.OneHotEncoder()
PropertyType_enc = enc.fit_transform(data).toarray()
PropertyType_enc.shape
# Out:
# (1811, 25)

# %%
X_cat = np.concatenate((neighborhood_enc,PropertyType_enc),axis=1)

# %%
X_cat = np.concatenate((X_cat,df['SiteEnergyUse_discrete'].to_numpy().reshape(-1,1)),axis=1)
X_cat.shape
# Out:
# (1811, 39)

# %%
X_quant = df[['YearBuilt', 'NumberofBuildings', 'NumberofFloors', 'PropertyGFABuilding(s)']]
X_quant.values.shape
# Out:
# (1811, 4)

# %%
X_cat.shape
# Out:
# (1811, 39)

# %%
Y_energy_log = df['SiteEnergyUse(kBtu)_log']
Y_ghg_log = df['GHGEmissions(MetricTonsCO2e)_log']
Y_energy_bis = df['SiteEnergyUse(kBtu)']
Y_ghg_bis = df['GHGEmissions(MetricTonsCO2e)']

# %%
X_cat_train, X_cat_test, X_quant_train, X_quant_test, Y_energy_log_train, Y_energy_log_test, Y_ghg_log_train, Y_ghg_log_test, Y_energy_bis_train, Y_energy_bis_test, Y_ghg_bis_train, Y_ghg_bis_test = train_test_split(X_cat, X_quant, Y_energy_log, Y_ghg_log, Y_energy_bis, Y_ghg_bis, test_size=0.3, stratify = df['PrimaryPropertyType'], random_state = 0)

# %%
std = preprocessing.StandardScaler()
X_quant_train_scaled = std.fit_transform(X_quant_train)
X_quant_test_scaled = std.transform(X_quant_test)

# %%
X_train = np.concatenate((X_cat_train,X_quant_train_scaled),axis=1)
X_test = np.concatenate((X_cat_test,X_quant_test_scaled),axis=1)

# %%
# Régression linéaire sur cibles en log
lr_energy = linear_model.LinearRegression()
lr_energy.fit(X_train,Y_energy_log_train)

print('R² test sur variable log:', round(metrics.r2_score(Y_energy_log_test,lr_energy.predict(X_test)),3))
print('R² test sur variable origine:', round(metrics.r2_score(np.expm1(Y_energy_log_test),np.expm1(lr_energy.predict(X_test))),3))

print('R² train sur variable log:',round(metrics.r2_score(Y_energy_log_train,lr_energy.predict(X_train)),3))
print('R² train sur variable orig:',round(metrics.r2_score(np.expm1(Y_energy_log_train),np.expm1(lr_energy.predict(X_train))),3))
# Out:
# R² test sur variable log: 0.807
# R² test sur variable origine: 0.376
# R² train sur variable log: 0.84
# R² train sur variable orig: -1.635

# %%
# Régression linéaire sur cibles non transformées
lr_energy_bis = linear_model.LinearRegression()
lr_energy_bis.fit(X_train,Y_energy_bis_train)

print('R² test :', round(metrics.r2_score(Y_energy_bis_test,lr_energy_bis.predict(X_test)),3))
print('R² train :',round(metrics.r2_score(Y_energy_bis_train,lr_energy_bis.predict(X_train)),3))
# Out:
# R² test : 0.386
# R² train : 0.859

# %%
recap_energy = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for energy')
recap_ghg = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for GHG')

# %%
recap_energy_log = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for energy log')
recap_ghg_log = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for GHG log')

# %%
def perf(X_train,Y_train,X_test,Y_test,model,hyperparam):
    
    '''Fonction permettant la recherche des meilleurs hyperparamètres d'un modèle puis 
    l'entrainement de ce modèle avec ces meilleurs paramètres sur le jeu X_train, Y_train
    La fonction retourne les performances du modèle (R², RMSE, temps d'éxécution) et les meilleurs paramètres
    
    le paramètre 'hyperparam' de la fonction est un dictionnaire
    
    Liste des hyperparamètres selon certains modèles :
    - Régression linéaire : pas d'hyperparamètre
    - Régression Ridge : alpha
    - Regression Lasso : alpha
    - Elasticnet : alpha et l1_ratio
    - SVR : estimator__C, estimator__epsilon et estimator__kernel
    - Random Forest : 
    '''
        
    model_gs = GridSearchCV(estimator = model, param_grid=hyperparam, cv=5)      
        
    model_gs.fit(X_train, Y_train)
    start_time = time.time()
    score = round(metrics.r2_score(Y_test,model_gs.predict(X_test)),5)     
    RMSE = round(metrics.mean_squared_error(Y_test,model_gs.predict(X_test), squared = False),5)
    pred_time = round(time.time()-start_time, 6)
    best_param = model_gs.best_params_
    for k, v in best_param.items():
        if type(v)!= str :
            best_param[k] = round(v, 6)
   
    return score, RMSE, pred_time, best_param



def recap_table(X_train,Y_energy_train,Y_ghg_train,X_test,Y_energy_test,Y_ghg_test,model,hyperparam):
    score, RMSE, pred_time, best_param = perf(X_train,Y_energy_train,X_test,Y_energy_test,model,hyperparam)
    recap_energy.loc[str(model),:] = [score,RMSE,pred_time,best_param]
    
    score, RMSE, pred_time, best_param = perf(X_train,Y_ghg_train,X_test,Y_ghg_test,model,hyperparam)
    recap_ghg.loc[str(model),:] = [score,RMSE,pred_time,best_param]

# %%
def perf_log(X_train,Y_train,X_test,Y_test,model,hyperparam):
    
    '''Fonction permettant la recherche des meilleurs hyperparamètres d'un modèle puis 
    l'entrainement de ce modèle avec ces meilleurs paramètres sur le jeu X_train, Y_train
    La fonction retourne les performances du modèle (R², RMSE, temps d'éxécution) et les meilleurs paramètres
    
    le paramètre 'hyperparam' de la fonction est un dictionnaire
    
    Liste des hyperparamètres selon certains modèles :
    - Régression linéaire : pas d'hyperparamètre
    - Régression Ridge : alpha
    - Regression Lasso : alpha
    - Elasticnet : alpha et l1_ratio
    - SVR : estimator__C, estimator__epsilon et estimator__kernel
    - Random Forest : 
    '''
        
    model_gs = GridSearchCV(estimator = model, param_grid=hyperparam, cv=5)      
        
    model_gs.fit(X_train, Y_train)
    start_time = time.time() 
    score = round(metrics.r2_score(np.expm1(Y_test),np.expm1(model_gs.predict(X_test))),5)     
    RMSE = round(metrics.mean_squared_error(np.expm1(Y_test),np.expm1(model_gs.predict(X_test)), squared = False),5)
    pred_time = round(time.time()-start_time, 6)
    best_param = model_gs.best_params_
    for k, v in best_param.items():
        if type(v)!= str :
            best_param[k] = round(v, 6)
   
    return score,RMSE, pred_time, best_param



def recap_table_log(X_train,Y_energy_train,Y_ghg_train,X_test,Y_energy_test,Y_ghg_test,model,hyperparam):
    score,RMSE, pred_time, best_param = perf_log(X_train,Y_energy_train,X_test,Y_energy_test,model,hyperparam)
    recap_energy_log.loc[str(model),:] = [score,RMSE,pred_time,best_param]
    
    score, RMSE, pred_time, best_param = perf_log(X_train,Y_ghg_train,X_test,Y_ghg_test,model,hyperparam)
    recap_ghg_log.loc[str(model),:] = [score,RMSE,pred_time,best_param]

# %%
LinearReg = linear_model.LinearRegression();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,LinearReg,{})

# %%
ridge = Ridge();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,ridge,{'alpha': np.logspace(-4,2,100)})

# %%
lasso = Lasso();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,lasso,{'alpha': np.logspace(-4,2,100)})
# Out:
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.72276672760878e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960976898599085e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8278369745802656e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583734497822768.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014137990737456.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722762887443183e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960977948692747e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8278241851162576e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583766579425328.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014136726768000.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722768295308592e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960975124081755e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.82782827313552e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583772603205664.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014123791835280.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7227675294531664e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960978115367037e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8278298075421824e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583771852841216.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014132834400416.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722763348203983e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960976791161141e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827825051219845e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583719549119216.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014135946652312.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722763344573052e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960973875631411e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827827382684232e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583772365810976.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014126924579912.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7227667640221136e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960974669414608e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8278278893470064e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583755416855728.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014133996273072.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722764502327091e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9609742842283424e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827826875462408e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583755307772080.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014140353843192.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7227647482667536e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960975718003765e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.82782850956272e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583763163687424.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014137148915160.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722763615967112e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960974658065563e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8278285121691504e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583749497056672.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014139704490192.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722764853162745e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9609768201421744e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8278281440638704e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583753254330752.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014129798487096.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7227666836581824e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9609756886976144e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8278283957250464e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583747581016688.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014138524985696.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7227642269014744e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9609749542370864e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8278289486181904e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583749167684016.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014136267621488.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722764795571507e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9609755435291184e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827827639112288e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583754586360304.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014136278594200.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7227657195212696e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9609753180183616e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827828607660725e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583751754741920.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014137246874616.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722765559620451e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9609753348191376e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827827905839669e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583753970179056.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014136748314792.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7227654578471984e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960976116647696e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827827536757763e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583752864648736.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014134819345424.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722765591587009e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9609760649003344e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827828378926891e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583750565807216.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014136958285240.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722765164665397e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.96097611921552e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827827685892749e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583750546907120.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014135365285080.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7227652137061976e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960975882538755e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827828379252701e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583753967535328.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014137109851616.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722765133555877e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960975599880621e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827828221468904e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583748437847648.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014135080976200.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722765198849951e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9609755768166976e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827828034177408e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583750084890576.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014135515493656.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7227651649689416e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960975906589136e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827828254783864e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583750725423520.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014135615606792.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722765132512284e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960975807915557e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827828026694349e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583751744847376.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014136215571448.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7227650853997744e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960975761857629e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8278281776373504e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583751349421520.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014136316979128.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722765217701521e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9609759609537264e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8278279762447856e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583750097664128.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014136126203416.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7227651672162576e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9609758713754016e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8278279928271696e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583749901034080.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014136151063232.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722765163802037e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960975935278429e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8278280483571136e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583750860219824.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014136217992200.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722765181448911e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960976014704461e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827828054176877e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583750227185792.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014136562957456.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7227651963872336e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960975962858264e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8278280964647776e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583750669935408.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014136185923472.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.722765124144336e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960975823018997e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8278280428917824e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583750265614272.0, tolerance: 114971048285677.8
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5014136903971136.0, tolerance: 105399385016250.38
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7227652827893744e+16, tolerance: 38396338269597.43
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.960975915902763e+16, tolerance: 119208479936553.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.827828093402005e+16, tolerance: 107415188282228.88
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13732654.98960203, tolerance: 43752.6493359184
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14647880.428527005, tolerance: 34264.345837214765
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15294789.670938894, tolerance: 52061.031513118585
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2840698.214304656, tolerance: 34908.94699464244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13531851.165970027, tolerance: 43752.6493359184
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14648321.411930569, tolerance: 34264.345837214765
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15295287.086892769, tolerance: 52061.031513118585
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2840909.534740269, tolerance: 34908.94699464244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3335326.18220298, tolerance: 43752.6493359184
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3640288.335453853, tolerance: 34264.345837214765
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15295857.796145812, tolerance: 52061.031513118585
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2841152.234585285, tolerance: 34908.94699464244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3335205.777496323, tolerance: 43752.6493359184
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3640579.8179223984, tolerance: 34264.345837214765
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15296512.388938494, tolerance: 52061.031513118585
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2841430.927124843, tolerance: 34908.94699464244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3335555.649365768, tolerance: 43752.6493359184
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3640914.6909916103, tolerance: 34264.345837214765
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15297262.917628475, tolerance: 52061.031513118585
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2841750.8889561445, tolerance: 34908.94699464244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3335957.4335287064, tolerance: 43752.6493359184
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3641299.368811697, tolerance: 34264.345837214765
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15298123.075229794, tolerance: 52061.031513118585
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2842118.151210338, tolerance: 34908.94699464244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3336418.747135386, tolerance: 43752.6493359184
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3641741.198551595, tolerance: 34264.345837214765
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15299108.388141096, tolerance: 52061.031513118585
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2851089.9140144438, tolerance: 34908.94699464244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3336948.2989387065, tolerance: 43752.6493359184
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3642248.592902258, tolerance: 34264.345837214765
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15300236.421132803, tolerance: 52061.031513118585
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2843413.571580246, tolerance: 34908.94699464244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3363190.422860846, tolerance: 43752.6493359184
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3642831.175879732, tolerance: 34264.345837214765
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15301526.990060821, tolerance: 52061.031513118585
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2843576.2700080276, tolerance: 34908.94699464244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3351835.177026853, tolerance: 43752.6493359184
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3643499.951646343, tolerance: 34264.345837214765
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15303002.376059175, tolerance: 52061.031513118585
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2844182.9444217384, tolerance: 34908.94699464244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3346870.4026245326, tolerance: 43752.6493359184
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3644267.488257289, tolerance: 34264.345837214765
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15304687.529765718, tolerance: 52061.031513118585
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2844907.795442939, tolerance: 34908.94699464244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3645148.1291730553, tolerance: 34264.345837214765
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3797331.6947651654, tolerance: 52061.031513118585
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2845741.991577849, tolerance: 34908.94699464244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3646158.2167233974, tolerance: 34264.345837214765
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125280.06855349243, tolerance: 52061.031513118585
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2846698.9013858736, tolerance: 34908.94699464244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3647316.3569007814, tolerance: 34264.345837214765
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2847795.78770186, tolerance: 34908.94699464244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3648643.684462011, tolerance: 34264.345837214765
#   model = cd_fast.enet_coordinate_descent(

# %%
svr = SVR(kernel = 'linear');
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,svr,{'C' : range(1,5),
                                       'epsilon' : np.linspace(0.1,1,10)})

# %%
svr = SVR();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,svr,{'C' : range(1,5),
                                        'epsilon' : np.linspace(0.1,1,10), 
                                       'kernel' : ['rbf','poly','sigmoid']})

# %%
rfr = RandomForestRegressor();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test, rfr, {'min_samples_split' : [2, 5, 10], 
                                             'min_samples_leaf' : [1, 2, 4], 
                                             'max_depth': range(5,16,1)})

# %%
gb = LGBMRegressor();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test, gb, {'n_estimators': [10, 50, 100, 200, 500],'max_depth':range(5,16, 2), 
                                                                                                     'learning_rate' : [0.0001,0.001,0.01,0.1,1], 
                                                                                                     'boosting_type' : ['gbdt','goss', 'dart'], 'num_leaves':[30]})

# %%
recap_energy
# Out:
#                               R²         RMSE Prediction time  \
# Model for energy
# LinearRegression()       0.38611  2.01297e+07        0.008005
# Ridge()                  0.38466  2.01534e+07               0
# Lasso()                  0.38634  2.01259e+07               0
# SVR(kernel='linear')    -0.04824   2.6304e+07        0.096026
# SVR()                   -0.04827  2.63043e+07        0.080019
# RandomForestRegressor()  0.39503  1.99828e+07        0.036428
# LGBMRegressor()          0.34784  2.07476e+07        0.008001
#
#                                                            Best parameters
# Model for energy
# LinearRegression()                                                      {}
# Ridge()                                                {'alpha': 4.037017}
# Lasso()                                                   {'alpha': 100.0}
# SVR(kernel='linear')                              {'C': 4, 'epsilon': 0.2}
# SVR()                           {'C': 4, 'epsilon': 0.1, 'kernel': 'poly'}
# RandomForestRegressor()  {'max_depth': 14, 'min_samples_leaf': 1, 'min_...
# LGBMRegressor()          {'boosting_type': 'gbdt', 'learning_rate': 0.1...

# %%
recap_ghg
# Out:
#                               R²     RMSE Prediction time  \
# Model for GHG
# LinearRegression()       0.23758  792.786               0
# Ridge()                  0.24167  790.659        0.008006
# Lasso()                  0.23356  794.873               0
# SVR(kernel='linear')     0.07697  872.301        0.121291
# SVR()                    0.01735  900.031        0.104043
# RandomForestRegressor()  0.26316  779.374        0.128034
# LGBMRegressor()          0.28849   765.86               0
#
#                                                            Best parameters
# Model for GHG
# LinearRegression()                                                      {}
# Ridge()                                                {'alpha': 1.519911}
# Lasso()                                                {'alpha': 8.111308}
# SVR(kernel='linear')                              {'C': 4, 'epsilon': 1.0}
# SVR()                        {'C': 4, 'epsilon': 1.0, 'kernel': 'sigmoid'}
# RandomForestRegressor()  {'max_depth': 13, 'min_samples_leaf': 1, 'min_...
# LGBMRegressor()          {'boosting_type': 'goss', 'learning_rate': 0.0...

# %%
LinearReg = linear_model.LinearRegression();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,LinearReg,{})

# %%
ridge = Ridge();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,ridge,{'alpha': np.logspace(-4,2,100)})

# %%
lasso = Lasso();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,lasso,{'alpha': np.logspace(-4,2,100)})

# %%
svr = SVR(kernel = 'linear');
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,svr,{'C' : range(1,5),
                                       'epsilon' : np.linspace(0.1,1,10)})

# %%
svr = SVR();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,svr,{'C' : range(1,5),
                                        'epsilon' : np.linspace(0.1,1,10), 
                                       'kernel' : ['rbf','poly','sigmoid']})

# %%
rfr = RandomForestRegressor();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test, rfr, {'min_samples_split' : [2, 5, 10], 
                                             'min_samples_leaf' : [1, 2, 4], 
                                             'max_depth': range(5,16,1)})

# %%
gb = LGBMRegressor();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test, gb, {'n_estimators': [10, 50, 100, 200, 500],'max_depth':range(5,16, 2), 
                                                                                                     'learning_rate' : [0.0001,0.001,0.01,0.1,1], 
                                                                                                     'boosting_type' : ['gbdt','goss', 'dart'], 'num_leaves':[30]})

# %%
recap_energy_log
# Out:
#                               R²         RMSE Prediction time  \
# Model for energy log
# LinearRegression()       0.37633  2.02894e+07        0.008008
# Ridge()                  0.36303  2.05045e+07               0
# Lasso()                  0.10804   2.4264e+07        0.007999
# SVR(kernel='linear')     0.37717  2.02757e+07        0.015636
# SVR()                    0.37021  2.03886e+07        0.046888
# RandomForestRegressor()   0.3352  2.09477e+07        0.031263
# LGBMRegressor()          0.33378    2.097e+07               0
#
#                                                            Best parameters
# Model for energy log
# LinearRegression()                                                      {}
# Ridge()                                                 {'alpha': 2.31013}
# Lasso()                                                {'alpha': 0.107227}
# SVR(kernel='linear')                              {'C': 4, 'epsilon': 0.6}
# SVR()                            {'C': 2, 'epsilon': 0.4, 'kernel': 'rbf'}
# RandomForestRegressor()  {'max_depth': 8, 'min_samples_leaf': 1, 'min_s...
# LGBMRegressor()          {'boosting_type': 'gbdt', 'learning_rate': 0.1...

# %%
recap_ghg_log
# Out:
#                               R²     RMSE Prediction time  \
# Model for GHG log
# LinearRegression()       0.28495  767.763               0
# Ridge()                  0.18264  820.852        0.015636
# Lasso()                  0.24788  787.414               0
# SVR(kernel='linear')     0.29797   760.74        0.065212
# SVR()                     0.2175  803.159        0.043004
# RandomForestRegressor()  0.25783  782.187        0.031263
# LGBMRegressor()          0.16329  830.513        0.031259
#
#                                                            Best parameters
# Model for GHG log
# LinearRegression()                                                      {}
# Ridge()                                                {'alpha': 9.326033}
# Lasso()                                                {'alpha': 0.001874}
# SVR(kernel='linear')                              {'C': 4, 'epsilon': 0.2}
# SVR()                            {'C': 2, 'epsilon': 0.6, 'kernel': 'rbf'}
# RandomForestRegressor()  {'max_depth': 9, 'min_samples_leaf': 1, 'min_s...
# LGBMRegressor()          {'boosting_type': 'goss', 'learning_rate': 0.0...
