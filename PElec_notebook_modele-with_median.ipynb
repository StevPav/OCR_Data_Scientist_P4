# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model, preprocessing, metrics
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVR
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from lightgbm import LGBMRegressor
import time

# %%
df = pd.read_csv('df_for_model.csv')
df = df.drop('Unnamed: 0',axis=1)

# %%
SiteEnergyUse_discrete = pd.qcut(df['SiteEnergyUse(kBtu)'],3, labels = False)
GHGEmission_discrete = pd.qcut(df['GHGEmissions(MetricTonsCO2e)'],3, labels = False)
df.insert(11, 'SiteEnergyUse_discrete', SiteEnergyUse_discrete)
df.insert(12, 'GHGEmission_discrete', GHGEmission_discrete)

# %%
df['SiteEnergyUse(kBtu)_log'] = np.log1p(df['SiteEnergyUse(kBtu)'])
df['GHGEmissions(MetricTonsCO2e)_log'] = np.log1p(df['GHGEmissions(MetricTonsCO2e)'])

# %%
df.columns
# Out:
# Index(['PrimaryPropertyType', 'Neighborhood', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFAParking', 'PropertyGFABuilding(s)',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'ENERGYSTARScore', 'SiteEnergyUse(kBtu)', 'SiteEnergyUse_discrete',
#        'GHGEmission_discrete', 'GHGEmissions(MetricTonsCO2e)',
#        'MedianEnergyUse', 'MedianGHGEmission', 'SiteEnergyUse(kBtu)_log',
#        'GHGEmissions(MetricTonsCO2e)_log'],
#       dtype='object')

# %%
data=df['Neighborhood'].values.reshape(-1,1)
enc = preprocessing.OneHotEncoder()
neighborhood_enc = enc.fit_transform(data).toarray()
neighborhood_enc.shape
# Out:
# (1811, 13)

# %%
data=df['PrimaryPropertyType'].values.reshape(-1,1)
enc = preprocessing.OneHotEncoder()
PropertyType_enc = enc.fit_transform(data).toarray()
PropertyType_enc.shape
# Out:
# (1811, 25)

# %%
X_cat = np.concatenate((neighborhood_enc,PropertyType_enc),axis=1)
X_cat.shape
# Out:
# (1811, 38)

# %%
#X_cat = np.concatenate((X_cat,df['SiteEnergyUse_discrete'].to_numpy().reshape(-1,1)),axis=1)

# %%
X_quant = df[['YearBuilt', 'NumberofBuildings', 'NumberofFloors', 'PropertyGFABuilding(s)','MedianEnergyUse','MedianGHGEmission']]
X_quant.values.shape
# Out:
# (1811, 6)

# %%
X_cat.shape
# Out:
# (1811, 38)

# %%
Y_energy_log = df['SiteEnergyUse(kBtu)_log']
Y_ghg_log = df['GHGEmissions(MetricTonsCO2e)_log']
Y_energy_bis = df['SiteEnergyUse(kBtu)']
Y_ghg_bis = df['GHGEmissions(MetricTonsCO2e)']

# %%
X_cat_train, X_cat_test, X_quant_train, X_quant_test, Y_energy_log_train, Y_energy_log_test, Y_ghg_log_train, Y_ghg_log_test, Y_energy_bis_train, Y_energy_bis_test, Y_ghg_bis_train, Y_ghg_bis_test = train_test_split(X_cat, X_quant, Y_energy_log, Y_ghg_log, Y_energy_bis, Y_ghg_bis, test_size=0.3, stratify = df['PrimaryPropertyType'], random_state = 1)

# %%
std = preprocessing.StandardScaler()
X_quant_train_scaled = std.fit_transform(X_quant_train)
X_quant_test_scaled = std.transform(X_quant_test)

# %%
X_train = np.concatenate((X_cat_train,X_quant_train_scaled),axis=1)
X_test = np.concatenate((X_cat_test,X_quant_test_scaled),axis=1)

# %%
# Régression linéaire sur cibles en log
lr_energy = linear_model.LinearRegression()
lr_energy.fit(X_train,Y_energy_log_train)

print('R² test sur variable log:', round(metrics.r2_score(Y_energy_log_test,lr_energy.predict(X_test)),3))
print('R² test sur variable origine:', round(metrics.r2_score(np.expm1(Y_energy_log_test),np.expm1(lr_energy.predict(X_test))),3))

print('R² train sur variable log:',round(metrics.r2_score(Y_energy_log_train,lr_energy.predict(X_train)),3))
print('R² train sur variable orig:',round(metrics.r2_score(np.expm1(Y_energy_log_train),np.expm1(lr_energy.predict(X_train))),3))
# Out:
# R² test sur variable log: -0.068
# R² test sur variable origine: -2.2114177507625553e+20
# R² train sur variable log: 0.563
# R² train sur variable orig: -10.263

# %%
# Régression linéaire sur cibles non transformées
lr_energy_bis = linear_model.LinearRegression()
lr_energy_bis.fit(X_train,Y_energy_bis_train)

print('R² test :', round(metrics.r2_score(Y_energy_bis_test,lr_energy_bis.predict(X_test)),3))
print('R² train :',round(metrics.r2_score(Y_energy_bis_train,lr_energy_bis.predict(X_train)),3))
# Out:
# R² test : 0.915
# R² train : 0.474

# %%
recap_energy = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for energy')
recap_ghg = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for GHG')

# %%
recap_energy_log = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for energy log')
recap_ghg_log = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for GHG log')

# %%
def perf(X_train,Y_train,X_test,Y_test,model,hyperparam):
    
    '''Fonction permettant la recherche des meilleurs hyperparamètres d'un modèle puis 
    l'entrainement de ce modèle avec ces meilleurs paramètres sur le jeu X_train, Y_train
    La fonction retourne les performances du modèle (R², RMSE, temps d'éxécution) et les meilleurs paramètres
    
    le paramètre 'hyperparam' de la fonction est un dictionnaire
    
    Liste des hyperparamètres selon certains modèles :
    - Régression linéaire : pas d'hyperparamètre
    - Régression Ridge : alpha
    - Regression Lasso : alpha
    - Elasticnet : alpha et l1_ratio
    - SVR : estimator__C, estimator__epsilon et estimator__kernel
    - Random Forest : 
    '''
        
    model_gs = GridSearchCV(estimator = model, param_grid=hyperparam, cv=5)      
        
    model_gs.fit(X_train, Y_train)
    start_time = time.time()
    score = round(metrics.r2_score(Y_test,model_gs.predict(X_test)),5)     
    RMSE = round(metrics.mean_squared_error(Y_test,model_gs.predict(X_test), squared = False),5)
    pred_time = round(time.time()-start_time, 6)
    best_param = model_gs.best_params_
    for k, v in best_param.items():
        if type(v)!= str :
            best_param[k] = round(v, 6)
   
    return score, RMSE, pred_time, best_param



def recap_table(X_train,Y_energy_train,Y_ghg_train,X_test,Y_energy_test,Y_ghg_test,model,hyperparam):
    score, RMSE, pred_time, best_param = perf(X_train,Y_energy_train,X_test,Y_energy_test,model,hyperparam)
    recap_energy.loc[str(model),:] = [score,RMSE,pred_time,best_param]
    
    score, RMSE, pred_time, best_param = perf(X_train,Y_ghg_train,X_test,Y_ghg_test,model,hyperparam)
    recap_ghg.loc[str(model),:] = [score,RMSE,pred_time,best_param]

# %%
def perf_log(X_train,Y_train,X_test,Y_test,model,hyperparam):
    
    '''Fonction permettant la recherche des meilleurs hyperparamètres d'un modèle puis 
    l'entrainement de ce modèle avec ces meilleurs paramètres sur le jeu X_train, Y_train
    La fonction retourne les performances du modèle (R², RMSE, temps d'éxécution) et les meilleurs paramètres
    
    le paramètre 'hyperparam' de la fonction est un dictionnaire
    
    Liste des hyperparamètres selon certains modèles :
    - Régression linéaire : pas d'hyperparamètre
    - Régression Ridge : alpha
    - Regression Lasso : alpha
    - Elasticnet : alpha et l1_ratio
    - SVR : estimator__C, estimator__epsilon et estimator__kernel
    - Random Forest : 
    '''
        
    model_gs = GridSearchCV(estimator = model, param_grid=hyperparam, cv=5)      
        
    model_gs.fit(X_train, Y_train)
    start_time = time.time()
    score = round(metrics.r2_score(np.expm1(Y_test),np.expm1(model_gs.predict(X_test))),5)     
    RMSE = round(metrics.mean_squared_error(np.expm1(Y_test),np.expm1(model_gs.predict(X_test)), squared = False),5)
    pred_time = round(time.time()-start_time, 6)
    best_param = model_gs.best_params_
    for k, v in best_param.items():
        if type(v)!= str :
            best_param[k] = round(v, 6)
   
    return score,RMSE, pred_time, best_param



def recap_table_log(X_train,Y_energy_train,Y_ghg_train,X_test,Y_energy_test,Y_ghg_test,model,hyperparam):
    score, RMSE, pred_time, best_param = perf_log(X_train,Y_energy_train,X_test,Y_energy_test,model,hyperparam)
    recap_energy_log.loc[str(model),:] = [score,RMSE,pred_time,best_param]
    
    score, RMSE, pred_time, best_param = perf_log(X_train,Y_ghg_train,X_test,Y_ghg_test,model,hyperparam)
    recap_ghg_log.loc[str(model),:] = [score,RMSE,pred_time,best_param]

# %%
LinearReg = linear_model.LinearRegression();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,LinearReg,{})

# %%
ridge = Ridge();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,ridge,{'alpha': np.logspace(-4,2,100)})

# %%
lasso = Lasso();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,lasso,{'alpha': np.logspace(-4,2,100)})
# Out:
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753877161594658e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293489297467364e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458461078265856e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697689687799354e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683854530035853e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753853543656437e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293486605837204e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458426826547747e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697705985432237e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683877752911813e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753842682492822e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293487052503425e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458451025998653e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697713887461046e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683860750110246e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.75387190673446e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2934870456158124e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.145842260954553e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.069770687344183e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.068383498137221e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753875992686982e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.29348469467069e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458425948809798e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697693268250733e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683864293072235e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753840259795195e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2934852621734056e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458441037180662e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697718301050278e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.06838527362476e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753858392497418e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293484596099803e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458443587226467e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697702873317907e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683856201695024e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753852054064502e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2934844973028292e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458445917379584e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697721022810666e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.068384857087354e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.75385579878713e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293485195168399e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.145843770480022e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.069771865346306e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.068384512541289e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753859683346026e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293484553337228e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458448122237917e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697717059533739e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683848686801346e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753868913368464e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2934840717988736e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458453271130195e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697717062222384e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.068384130336785e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.75385772536538e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2934840379005268e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458443589719134e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.069772224508324e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.06838428826929e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753867395863088e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2934839361521944e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458449561476744e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697719078003446e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683845767850933e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753851574269587e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2934835606747656e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458448752487544e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697718066497856e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683847659935738e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753854484801986e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293484077895724e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458451201452054e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697722124269555e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683846243147344e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753850751114493e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293484177641562e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458452530174317e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697720599694426e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683844346810741e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.7538517041476e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2934843286930508e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458448288977094e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697720965374445e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683846831540989e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753855063907235e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293483864185181e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458452842315434e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697721262255643e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683845941742222e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753856180736325e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293483747639223e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.145845238092889e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.069771974470342e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683846929555085e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753855205293389e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293484132924981e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458450631811514e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.069771972889063e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.068384619539526e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753854630097856e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2934837197498764e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458451007929571e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697721490908998e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683845604183746e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753853656106347e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293483590611573e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458451810245536e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697721971085507e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683844547637891e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.75385465125575e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2934837618739296e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458451539792869e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697721200405043e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683844917230699e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753853029333936e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293483806500493e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.145845233132136e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697721700740038e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683845499276472e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753853080522518e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2934838547530016e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458452776963288e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.069772116690662e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.068384445842284e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753853215484224e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293483791019755e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458452813341112e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697721791678893e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683845640844413e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753852614281086e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2934837786253544e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.14584532283739e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697721410663195e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683845019191248e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753853601195533e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2934837739704144e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458452619200778e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.069772116848513e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683844816040275e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753852143736669e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293483818692281e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458453219027002e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697721512194768e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0683845513601291e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753852753041206e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2934838155097756e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458452905432386e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697721590013382e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.068384482896545e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.753852989614342e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293483863657295e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.145845309544735e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0697721517169904e+17, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.068384473431364e+17, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.75385317138891e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.293483875762038e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1458453095646557e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35427520.68843159, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119452666.79399833, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18779321.548588276, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 95478505.68553326, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 114845152.2183625, tolerance: 58234.200620825985
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31825777.433526337, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119469105.90159428, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18474335.416683555, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92237384.6663646, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119860532.73718269, tolerance: 58234.200620825985
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31831768.967013884, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119391393.22612692, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18211659.89128396, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94250220.64895266, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100077550.51314087, tolerance: 58234.200620825985
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39236361.55316852, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119994597.3958908, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17985322.18950039, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94884296.83725408, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6490113.958200812, tolerance: 58234.200620825985
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39266586.615015455, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119422083.38855506, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17790562.537649333, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 101290301.29782066, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34406535.160984576, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120193880.66761982, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17622190.758643597, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 69142888.89977905, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33920232.92369251, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96093400.50491504, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17440530.899546623, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51662257.081683725, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4580520.973419204, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96149777.47722526, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17040559.176974118, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39207544.67703387, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49054.890619665384, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94749311.80682147, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17216621.38829297, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35307209.035695344, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26513985.481443852, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3706411.420192957, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35258646.86285627, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3362354.852206826, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35218400.98512781, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3106463.495820403, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3137389.3008708954, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3212070.4260017276, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3304958.908172488, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3386635.864342153, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3458581.05586946, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3522174.456890881, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3260262.7573143244, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(

# %%
svr = SVR(kernel = 'linear');
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,svr,{'C' : range(1,5),
                                       'epsilon' : np.linspace(0.1,1,10)})

# %%
svr = SVR();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,svr,{'C' : range(1,5),
                                        'epsilon' : np.linspace(0.1,1,10), 
                                       'kernel' : ['rbf','poly','sigmoid']})

# %%
rfr = RandomForestRegressor();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test, rfr, {'min_samples_split' : [2, 5, 10], 
                                             'min_samples_leaf' : [1, 2, 4], 
                                             'max_depth': range(5,16,1)})

# %%
gb = LGBMRegressor();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test, gb, {'n_estimators': [10, 50, 100, 200, 500],'max_depth':range(5,16, 2), 
                                                                                                     'learning_rate' : [0.0001,0.001,0.01,0.1,1], 
                                                                                                     'boosting_type' : ['gbdt','goss', 'dart'], 'num_leaves':[30]})

# %%
recap_energy
# Out:
#                               R²         RMSE Prediction time  \
# Model for energy
# LinearRegression()       0.91516  1.18936e+07        0.002998
# Ridge()                  0.88646  1.37591e+07           0.001
# Lasso()                  0.91531  1.18832e+07        0.001002
# SVR(kernel='linear')    -0.02299  4.13006e+07        0.038002
# SVR()                    0.41924  3.11185e+07        0.046004
# RandomForestRegressor()  0.26273  3.50619e+07        0.025002
# LGBMRegressor()          0.30136   3.4131e+07           0.004
#
#                                                            Best parameters
# Model for energy
# LinearRegression()                                                      {}
# Ridge()                                                   {'alpha': 100.0}
# Lasso()                                                   {'alpha': 100.0}
# SVR(kernel='linear')                              {'C': 4, 'epsilon': 0.1}
# SVR()                           {'C': 4, 'epsilon': 0.1, 'kernel': 'poly'}
# RandomForestRegressor()  {'max_depth': 12, 'min_samples_leaf': 2, 'min_...
# LGBMRegressor()          {'boosting_type': 'goss', 'learning_rate': 0.1...

# %%
recap_ghg
# Out:
#                               R²     RMSE Prediction time  \
# Model for GHG
# LinearRegression()       0.62522   468.31           0.001
# Ridge()                  0.67806  434.047           0.001
# Lasso()                  0.69572   421.97           0.002
# SVR(kernel='linear')     0.61031  477.534        0.037013
# SVR()                    0.08284  732.605        0.116251
# RandomForestRegressor()   0.5563  509.556        0.047003
# LGBMRegressor()          0.54853  513.998        0.021002
#
#                                                            Best parameters
# Model for GHG
# LinearRegression()                                                      {}
# Ridge()                                                   {'alpha': 100.0}
# Lasso()                                                 {'alpha': 86.9749}
# SVR(kernel='linear')                              {'C': 3, 'epsilon': 1.0}
# SVR()                        {'C': 4, 'epsilon': 0.4, 'kernel': 'sigmoid'}
# RandomForestRegressor()  {'max_depth': 14, 'min_samples_leaf': 2, 'min_...
# LGBMRegressor()          {'boosting_type': 'goss', 'learning_rate': 0.0...

# %%
LinearReg = linear_model.LinearRegression();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,LinearReg,{})

# %%
ridge = Ridge();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,ridge,{'alpha': np.logspace(-4,2,100)})

# %%
lasso = Lasso();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,lasso,{'alpha': np.logspace(-4,2,100)})
# Out:
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.397976848341727, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 204.82990178989624, tolerance: 0.18948116299514178
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 251.60676334940408, tolerance: 0.19359686915879712
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5319879570813555, tolerance: 0.18472003636253237
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.102270603989609, tolerance: 0.18956612146077104
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4535877891762539, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 204.9651690068583, tolerance: 0.18948116299514178
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76.92915916939774, tolerance: 0.19359686915879712
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.827929092630029, tolerance: 0.18956612146077104
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8403604007102103, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 205.13730128630255, tolerance: 0.18948116299514178
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.606169441364386, tolerance: 0.19359686915879712
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.1974397945458577, tolerance: 0.18956612146077104
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8037365324967141, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 205.32713611764422, tolerance: 0.18948116299514178
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17.399583092424223, tolerance: 0.19359686915879712
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.345925248850449, tolerance: 0.18956612146077104
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8117847494906982, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153.7401715134804, tolerance: 0.18948116299514178
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9417844738878784, tolerance: 0.18956612146077104
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8266507912486531, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.083592773763712, tolerance: 0.18948116299514178
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8522715109767205, tolerance: 0.18956612146077104
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8443060144865058, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8386917213404104, tolerance: 0.18956612146077104
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8643452679173151, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 290.56683933603216, tolerance: 0.22546119608391002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 276.3177796286892, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119.93649481971374, tolerance: 0.22271582040500962
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7333685344513015, tolerance: 0.20996653158383044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3094729078641194, tolerance: 0.22370831760507717
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 290.762523137786, tolerance: 0.22546119608391002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 276.49049325974175, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119.94692387584428, tolerance: 0.22271582040500962
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.741296572158717, tolerance: 0.20996653158383044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.20771157596778, tolerance: 0.22546119608391002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 276.68652733640596, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120.00647887601895, tolerance: 0.22271582040500962
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7501570157517108, tolerance: 0.20996653158383044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.008856299125, tolerance: 0.22546119608391002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 276.90787558273144, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120.098636478951, tolerance: 0.22271582040500962
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.72888510118878, tolerance: 0.22546119608391002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 277.1563461271235, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120.22032294865403, tolerance: 0.22271582040500962
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6251419570298822, tolerance: 0.22546119608391002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 277.4335974352576, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120.41309974788464, tolerance: 0.22271582040500962
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26834014686414775, tolerance: 0.22546119608391002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115.99878068289024, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.2733641740358053, tolerance: 0.22271582040500962
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.493914861963276, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(

# %%
svr = SVR(kernel = 'linear');
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,svr,{'C' : range(1,5),
                                       'epsilon' : np.linspace(0.1,1,10)})

# %%
svr = SVR();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,svr,{'C' : range(1,5),
                                        'epsilon' : np.linspace(0.1,1,10), 
                                       'kernel' : ['rbf','poly','sigmoid']})

# %%
rfr = RandomForestRegressor();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test, rfr, {'min_samples_split' : [2, 5, 10], 
                                             'min_samples_leaf' : [1, 2, 4], 
                                             'max_depth': range(5,16,1)})

# %%
gb = LGBMRegressor();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test, gb, {'n_estimators': [10, 50, 100, 200, 500],'max_depth':range(5,16, 2), 
                                                                                                     'learning_rate' : [0.0001,0.001,0.01,0.1,1], 
                                                                                                     'boosting_type' : ['gbdt','goss', 'dart'], 'num_leaves':[30]})

# %%
recap_energy_log
# Out:
#                                   R²         RMSE Prediction time  \
# Model for energy log
# LinearRegression()      -2.21142e+20  6.07236e+17        0.001999
# Ridge()                  -4.5979e+20  8.75592e+17           0.002
# Lasso()                 -1.68131e+21  1.67435e+18        0.001001
# SVR(kernel='linear')    -4.04102e+27  2.59578e+21        0.016004
# SVR()                        0.10019  3.87344e+07        0.081006
# RandomForestRegressor()      0.30935  3.39352e+07        0.045003
# LGBMRegressor()              0.26063  3.51118e+07        0.013003
#
#                                                            Best parameters
# Model for energy log
# LinearRegression()                                                      {}
# Ridge()                                                {'alpha': 3.053856}
# Lasso()                                                {'alpha': 0.002848}
# SVR(kernel='linear')                              {'C': 4, 'epsilon': 0.7}
# SVR()                            {'C': 3, 'epsilon': 0.2, 'kernel': 'rbf'}
# RandomForestRegressor()  {'max_depth': 12, 'min_samples_leaf': 1, 'min_...
# LGBMRegressor()          {'boosting_type': 'gbdt', 'learning_rate': 0.1...

# %%
recap_ghg_log
# Out:
#                                   R²         RMSE Prediction time  \
# Model for GHG log
# LinearRegression()      -4.22059e+20  1.57157e+13        0.000997
# Ridge()                 -5.32715e+20  1.76561e+13        0.001999
# Lasso()                 -7.75692e+20  2.13055e+13        0.002001
# SVR(kernel='linear')    -4.43107e+27  5.09216e+16        0.037001
# SVR()                        0.16301      699.855        0.090009
# RandomForestRegressor()      0.48017      551.542        0.058004
# LGBMRegressor()              0.42378      580.688        0.024003
#
#                                                            Best parameters
# Model for GHG log
# LinearRegression()                                                      {}
# Ridge()                                                {'alpha': 5.336699}
# Lasso()                                                {'alpha': 0.002154}
# SVR(kernel='linear')                              {'C': 1, 'epsilon': 0.3}
# SVR()                            {'C': 2, 'epsilon': 0.3, 'kernel': 'rbf'}
# RandomForestRegressor()  {'max_depth': 13, 'min_samples_leaf': 1, 'min_...
# LGBMRegressor()          {'boosting_type': 'gbdt', 'learning_rate': 0.0...
