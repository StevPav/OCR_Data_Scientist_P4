# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model, preprocessing, metrics
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVR
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from lightgbm import LGBMRegressor
import time

# %%
df = pd.read_csv('df_for_model.csv')
df = df.drop('Unnamed: 0',axis=1)

# %%
SiteEnergyUse_discrete = pd.qcut(df['SiteEnergyUse(kBtu)'],3, labels = False)
GHGEmission_discrete = pd.qcut(df['GHGEmissions(MetricTonsCO2e)'],3, labels = False)
df.insert(11, 'SiteEnergyUse_discrete', SiteEnergyUse_discrete)
df.insert(12, 'GHGEmission_discrete', GHGEmission_discrete)

# %%
df['SiteEnergyUse(kBtu)_log'] = np.log1p(df['SiteEnergyUse(kBtu)'])
df['GHGEmissions(MetricTonsCO2e)_log'] = np.log1p(df['GHGEmissions(MetricTonsCO2e)'])

# %%
#df=df.drop(df[df['PrimaryPropertyType']=='Hospital'].index)

# %%
df.columns
# Out:
# Index(['PrimaryPropertyType', 'Neighborhood', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFAParking', 'PropertyGFABuilding(s)',
#        'ListOfAllPropertyUseTypes', 'LargestPropertyUseType',
#        'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseType',
#        'SiteEnergyUse_discrete', 'GHGEmission_discrete',
#        'SecondLargestPropertyUseTypeGFA', 'ENERGYSTARScore',
#        'SiteEnergyUse(kBtu)', 'GHGEmissions(MetricTonsCO2e)',
#        'MedianEnergyUse', 'MedianGHGEmission', 'SiteEnergyUse(kBtu)_log',
#        'GHGEmissions(MetricTonsCO2e)_log'],
#       dtype='object')

# %%
data=df['Neighborhood'].values.reshape(-1,1)
enc = preprocessing.OneHotEncoder()
neighborhood_enc = enc.fit_transform(data).toarray()
neighborhood_enc.shape
# Out:
# (1811, 13)

# %%
data=df['PrimaryPropertyType'].values.reshape(-1,1)
enc = preprocessing.OneHotEncoder()
PropertyType_enc = enc.fit_transform(data).toarray()
PropertyType_enc.shape
# Out:
# (1811, 25)

# %%
X_cat = np.concatenate((neighborhood_enc,PropertyType_enc),axis=1)
X_cat.shape
# Out:
# (1811, 38)

# %%
#X_cat = np.concatenate((X_cat,df['SiteEnergyUse_discrete'].to_numpy().reshape(-1,1)),axis=1)

# %%
X_quant = df[['YearBuilt', 'NumberofBuildings', 'NumberofFloors', 'PropertyGFABuilding(s)','PropertyGFAParking','LargestPropertyUseTypeGFA','SecondLargestPropertyUseTypeGFA','MedianEnergyUse','MedianGHGEmission']]
X_quant.values.shape
# Out:
# (1811, 9)

# %%
X_cat.shape
# Out:
# (1811, 38)

# %%
Y_energy_log = df['SiteEnergyUse(kBtu)_log']
Y_ghg_log = df['GHGEmissions(MetricTonsCO2e)_log']
Y_energy_bis = df['SiteEnergyUse(kBtu)']
Y_ghg_bis = df['GHGEmissions(MetricTonsCO2e)']

# %%
X_cat_train, X_cat_test, X_quant_train, X_quant_test, Y_energy_log_train, Y_energy_log_test, Y_ghg_log_train, Y_ghg_log_test, Y_energy_bis_train, Y_energy_bis_test, Y_ghg_bis_train, Y_ghg_bis_test = train_test_split(X_cat, X_quant, Y_energy_log, Y_ghg_log, Y_energy_bis, Y_ghg_bis, test_size=0.3, stratify = df['PrimaryPropertyType'], random_state = 1)

# %%
std = preprocessing.StandardScaler()
X_quant_train_scaled = std.fit_transform(X_quant_train)
X_quant_test_scaled = std.transform(X_quant_test)

# %%
X_train = np.concatenate((X_cat_train,X_quant_train_scaled),axis=1)
X_test = np.concatenate((X_cat_test,X_quant_test_scaled),axis=1)

# %%
# Régression linéaire sur cibles en log
lr_energy = linear_model.LinearRegression()
lr_energy.fit(X_train,Y_energy_log_train)

print('R² test sur variable log:', round(metrics.r2_score(Y_energy_log_test,lr_energy.predict(X_test)),3))
print('R² test sur variable origine:', round(metrics.r2_score(np.expm1(Y_energy_log_test),np.expm1(lr_energy.predict(X_test))),3))

print('R² train sur variable log:',round(metrics.r2_score(Y_energy_log_train,lr_energy.predict(X_train)),3))
print('R² train sur variable orig:',round(metrics.r2_score(np.expm1(Y_energy_log_train),np.expm1(lr_energy.predict(X_train))),3))
# Out:
# R² test sur variable log: -0.093
# R² test sur variable origine: -6.349152415228415e+20
# R² train sur variable log: 0.566
# R² train sur variable orig: -8.909

# %%
# Régression linéaire sur cibles non transformées
lr_energy_bis = linear_model.LinearRegression()
lr_energy_bis.fit(X_train,Y_energy_bis_train)

print('R² test :', round(metrics.r2_score(Y_energy_bis_test,lr_energy_bis.predict(X_test)),3))
print('R² train :',round(metrics.r2_score(Y_energy_bis_train,lr_energy_bis.predict(X_train)),3))
# Out:
# R² test : 0.872
# R² train : 0.566

# %%
recap_energy = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for energy')
recap_ghg = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for GHG')

# %%
recap_energy_log = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for energy log')
recap_ghg_log = pd.DataFrame(columns = ['R²','RMSE','Prediction time','Best parameters']).rename_axis('Model for GHG log')

# %%
def perf(X_train,Y_train,X_test,Y_test,model,hyperparam):
    
    '''Fonction permettant la recherche des meilleurs hyperparamètres d'un modèle puis 
    l'entrainement de ce modèle avec ces meilleurs paramètres sur le jeu X_train, Y_train
    La fonction retourne les performances du modèle (R², RMSE, temps d'éxécution) et les meilleurs paramètres
    
    le paramètre 'hyperparam' de la fonction est un dictionnaire
    
    Liste des hyperparamètres selon certains modèles :
    - Régression linéaire : pas d'hyperparamètre
    - Régression Ridge : alpha
    - Regression Lasso : alpha
    - Elasticnet : alpha et l1_ratio
    - SVR : estimator__C, estimator__epsilon et estimator__kernel
    - Random Forest : 
    '''
        
    model_gs = GridSearchCV(estimator = model, param_grid=hyperparam, cv=5)      
        
    model_gs.fit(X_train, Y_train)
    start_time = time.time()
    score = round(metrics.r2_score(Y_test,model_gs.predict(X_test)),5)     
    RMSE = round(metrics.mean_squared_error(Y_test,model_gs.predict(X_test), squared = False),5)
    pred_time = round(time.time()-start_time, 6)
    best_param = model_gs.best_params_
    for k, v in best_param.items():
        if type(v)!= str :
            best_param[k] = round(v, 6)
   
    return score, RMSE, pred_time, best_param



def recap_table(X_train,Y_energy_train,Y_ghg_train,X_test,Y_energy_test,Y_ghg_test,model,hyperparam):
    score, RMSE, pred_time, best_param = perf(X_train,Y_energy_train,X_test,Y_energy_test,model,hyperparam)
    recap_energy.loc[str(model),:] = [score,RMSE,pred_time,best_param]
    
    score, RMSE, pred_time, best_param = perf(X_train,Y_ghg_train,X_test,Y_ghg_test,model,hyperparam)
    recap_ghg.loc[str(model),:] = [score,RMSE,pred_time,best_param]

# %%
def perf_log(X_train,Y_train,X_test,Y_test,model,hyperparam):
    
    '''Fonction permettant la recherche des meilleurs hyperparamètres d'un modèle puis 
    l'entrainement de ce modèle avec ces meilleurs paramètres sur le jeu X_train, Y_train
    La fonction retourne les performances du modèle (R², RMSE, temps d'éxécution) et les meilleurs paramètres
    
    le paramètre 'hyperparam' de la fonction est un dictionnaire
    
    Liste des hyperparamètres selon certains modèles :
    - Régression linéaire : pas d'hyperparamètre
    - Régression Ridge : alpha
    - Regression Lasso : alpha
    - Elasticnet : alpha et l1_ratio
    - SVR : estimator__C, estimator__epsilon et estimator__kernel
    - Random Forest : 
    '''
        
    model_gs = GridSearchCV(estimator = model, param_grid=hyperparam, cv=5)      
        
    model_gs.fit(X_train, Y_train)
    start_time = time.time()
    score = round(metrics.r2_score(np.expm1(Y_test),np.expm1(model_gs.predict(X_test))),5)     
    RMSE = round(metrics.mean_squared_error(np.expm1(Y_test),np.expm1(model_gs.predict(X_test)), squared = False),5)
    pred_time = round(time.time()-start_time, 6)
    best_param = model_gs.best_params_
    for k, v in best_param.items():
        if type(v)!= str :
            best_param[k] = round(v, 6)
   
    return score,RMSE, pred_time, best_param



def recap_table_log(X_train,Y_energy_train,Y_ghg_train,X_test,Y_energy_test,Y_ghg_test,model,hyperparam):
    score, RMSE, pred_time, best_param = perf_log(X_train,Y_energy_train,X_test,Y_energy_test,model,hyperparam)
    recap_energy_log.loc[str(model),:] = [score,RMSE,pred_time,best_param]
    
    score, RMSE, pred_time, best_param = perf_log(X_train,Y_ghg_train,X_test,Y_ghg_test,model,hyperparam)
    recap_ghg_log.loc[str(model),:] = [score,RMSE,pred_time,best_param]

# %%
LinearReg = linear_model.LinearRegression();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,LinearReg,{})

# %%
ridge = Ridge();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,ridge,{'alpha': np.logspace(-4,2,100)})

# %%
lasso = Lasso();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,lasso,{'alpha': np.logspace(-4,2,100)})
# Out:
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.05810146065088e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017272679475395e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112040734720552e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604904770300918e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184211525277173e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058116975868872e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017269435827275e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112047347569294e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604918202467827e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.18420825192136e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058131394147286e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017272181375245e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112051937143394e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604921393322472e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184213654353142e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058105013983328e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017269270184621e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112049718963069e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604914342178186e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184194818212296e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058117149382077e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017272818085064e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112059153641075e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604920004109568e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184200365442915e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058111788088518e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0172694636986196e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112039895276627e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604920357526038e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184207701858429e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058104435502774e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0172678837909204e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112044528259685e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604915848969035e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184205696978963e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058109296625414e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017269038959475e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112052698385446e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.60491800897019e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184205173092147e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058108320360203e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017269184035075e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112053116851826e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604913865357056e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184201187551568e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058116694508384e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017268635369943e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.011204416162087e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604915880423568e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184203250919494e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058114032469629e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017269745792188e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112048613840397e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604915314035234e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184200571231536e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058114090546624e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.01726914448098e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112046658803683e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604917881180614e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184203937287627e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058110286767162e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0172686643898024e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112047870805288e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604915785747693e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.18419939037461e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058110040743478e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0172689763224748e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112047872810451e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604917083146648e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184201984207126e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.05810940416895e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0172693778988624e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112047645677739e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604915667966547e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184202161995758e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058109439611578e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017268499159687e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112047583112912e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604916415524653e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184202922654952e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058110948167938e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017268675497052e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112046626389077e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604918079216992e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.18420047633838e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058110531377054e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017268658957028e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112046107822126e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.60491654220791e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184201089875658e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058110929667658e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0172683728119424e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112047089997862e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604917177590138e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184201936271666e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.05811152911377e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0172683958723844e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112047106392906e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604916703598275e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184201007816563e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058110499922723e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0172679791416028e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112046775941485e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604917255526662e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184201240281074e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.05810958866818e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0172686396525236e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112046766960422e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604917140422277e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184201987943853e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058110386988683e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017268495468469e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112047017619398e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604917569763485e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.18420192763505e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058110006688544e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017268511789539e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112046538596237e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.60491669932446e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184200782398723e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058109408648278e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0172682527023944e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112047034153125e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604916842710026e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184201417816814e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058109568172942e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0172685092537224e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112047094346963e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604917090684336e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184201383147928e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.0581100962717e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0172685310658704e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112047065281411e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604916807666293e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184201239216488e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058109772512416e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0172684502339264e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112046936807155e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.60491718490406e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184201033464304e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058110091807245e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017268472881221e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.011204697440679e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604916831871312e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184201143341774e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058110034618808e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017268458974163e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112047180945302e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604917380100525e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.184201085423173e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058109767153574e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.017268463593944e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112046832680155e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.604917047900842e+16, tolerance: 51916133344796.42
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.18420116721264e+16, tolerance: 59511348513315.2
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.058110064088874e+16, tolerance: 56314712393550.78
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0172684938191492e+16, tolerance: 35302160439502.13
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0112047014177829e+17, tolerance: 63166560028773.97
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99059427.46592829, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51634915.56473325, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85224147.18426147, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92865674.68760052, tolerance: 58234.200620825985
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36723912.94991398, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85786228.34438723, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49451683.421525285, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85192879.68584704, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8795040.439586878, tolerance: 58234.200620825985
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31649044.29328062, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89238552.4176711, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49405553.619976595, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85203331.54275665, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8263709.643686831, tolerance: 58234.200620825985
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31629367.75289462, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89807229.87460089, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26524659.005515188, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51246459.710735366, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8268911.555750161, tolerance: 58234.200620825985
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34541829.12966815, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89905592.1123172, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25480844.9063465, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33128596.27065, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8242018.201383501, tolerance: 58234.200620825985
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29596602.69941224, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 71330382.32303523, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25072630.183079243, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33140718.1998505, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8103184.191771328, tolerance: 58234.200620825985
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27166800.38873314, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 69827221.92991082, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25161957.193463415, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31607510.09099248, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7984503.156430006, tolerance: 58234.200620825985
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24628355.29681223, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 68787487.62981641, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20132887.499083966, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23140824.235040188, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7883494.887050658, tolerance: 58234.200620825985
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 180563.7291701883, tolerance: 34902.10224227449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10434673.143554598, tolerance: 63204.22599137044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25741313.085138857, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8518457.087055415, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7851118.42236203, tolerance: 58234.200620825985
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21642931.058986932, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4983898.579455674, tolerance: 61211.800763062645
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7835023.052181423, tolerance: 58234.200620825985
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15281146.622997224, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1265398.339812249, tolerance: 58234.200620825985
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10987853.678258121, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8080432.419100165, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7555652.972016454, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109694.48023375869, tolerance: 47627.40236216817
#   model = cd_fast.enet_coordinate_descent(

# %%
svr = SVR(kernel = 'linear');
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,svr,{'C' : range(1,5),
                                       'epsilon' : np.linspace(0.1,1,10)})

# %%
svr = SVR();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test,svr,{'C' : range(1,5),
                                        'epsilon' : np.linspace(0.1,1,10), 
                                       'kernel' : ['rbf','poly','sigmoid']})

# %%
rfr = RandomForestRegressor();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test, rfr, {'min_samples_split' : [2, 5, 10], 
                                             'min_samples_leaf' : [1, 2, 4], 
                                             'max_depth': range(5,16,1)})

# %%
gb = LGBMRegressor();
recap_table(X_train,Y_energy_bis_train,Y_ghg_bis_train,X_test,Y_energy_bis_test,Y_ghg_bis_test, gb, {'n_estimators': [150],'max_depth':range(5,16), 
                                                                                                     'learning_rate' : [0.0001,0.001,0.01,0.1,1], 
                                                                                                     'boosting_type' : ['gbdt','goss', 'dart'], 'num_leaves':[30]})

# %%
recap_energy
# Out:
#                               R²         RMSE Prediction time  \
# Model for energy
# LinearRegression()       0.87238  1.45874e+07        0.001002
# Ridge()                  0.84653   1.5997e+07           0.001
# Lasso()                  0.87328  1.45359e+07        0.001001
# SVR(kernel='linear')    -0.02275  4.12958e+07        0.060001
# SVR()                    0.29119  3.43786e+07        0.079027
# RandomForestRegressor()  0.32649  3.35116e+07        0.039449
# LGBMRegressor()          0.24223   3.5546e+07            0.01
#
#                                                            Best parameters
# Model for energy
# LinearRegression()                                                      {}
# Ridge()                                                   {'alpha': 100.0}
# Lasso()                                                   {'alpha': 100.0}
# SVR(kernel='linear')                              {'C': 4, 'epsilon': 0.2}
# SVR()                           {'C': 4, 'epsilon': 0.1, 'kernel': 'poly'}
# RandomForestRegressor()  {'max_depth': 12, 'min_samples_leaf': 4, 'min_...
# LGBMRegressor()          {'boosting_type': 'goss', 'learning_rate': 0.0...

# %%
recap_ghg
# Out:
#                               R²     RMSE Prediction time  \
# Model for GHG
# LinearRegression()        0.5778  497.058           0.002
# Ridge()                  0.71046  411.626        0.002001
# Lasso()                  0.67173  438.294           0.002
# SVR(kernel='linear')     0.61975  471.719        0.059004
# SVR()                    0.06885  738.172        0.114009
# RandomForestRegressor()  0.53973  518.982        0.030002
# LGBMRegressor()          0.69531  422.257        0.014003
#
#                                                            Best parameters
# Model for GHG
# LinearRegression()                                                      {}
# Ridge()                                                   {'alpha': 100.0}
# Lasso()                                                   {'alpha': 100.0}
# SVR(kernel='linear')                              {'C': 3, 'epsilon': 0.4}
# SVR()                        {'C': 4, 'epsilon': 0.3, 'kernel': 'sigmoid'}
# RandomForestRegressor()  {'max_depth': 11, 'min_samples_leaf': 4, 'min_...
# LGBMRegressor()          {'boosting_type': 'goss', 'learning_rate': 0.1...

# %%
LinearReg = linear_model.LinearRegression();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,LinearReg,{})

# %%
ridge = Ridge();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,ridge,{'alpha': np.logspace(-4,2,100)})

# %%
lasso = Lasso();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,lasso,{'alpha': np.logspace(-4,2,100)})
# Out:
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.775897861078533, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 203.64422457501303, tolerance: 0.18948116299514178
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 250.11383657263235, tolerance: 0.19359686915879712
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.48050045127843, tolerance: 0.18956612146077104
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0680080384406665, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 203.79609137246052, tolerance: 0.18948116299514178
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133.02151350057522, tolerance: 0.19359686915879712
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.01317588371478, tolerance: 0.18956612146077104
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.805160553447763, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 203.9687665227512, tolerance: 0.18948116299514178
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22.115630166374444, tolerance: 0.19359686915879712
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.331149258802725, tolerance: 0.18956612146077104
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7958026581056856, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 204.15928792577157, tolerance: 0.18948116299514178
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.75833768943437, tolerance: 0.19359686915879712
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9684221330799119, tolerance: 0.18956612146077104
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.807392275387997, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92.07986458901286, tolerance: 0.18948116299514178
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6708871691336071, tolerance: 0.19359686915879712
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.238414797310611, tolerance: 0.18956612146077104
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8230080985767927, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.212760875947879, tolerance: 0.18948116299514178
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9233433323455529, tolerance: 0.18956612146077104
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8410249351784387, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8580863628693578, tolerance: 0.18956612146077104
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8614003875414937, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.88430408701754, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5124242111285184, tolerance: 0.18940016219726957
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 288.97111552878516, tolerance: 0.22546119608391002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 275.7832891349843, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119.44038785326836, tolerance: 0.22271582040500962
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 288.819864039229, tolerance: 0.22546119608391002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 275.9651152444432, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119.4766765645029, tolerance: 0.22271582040500962
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102.96529985031316, tolerance: 0.22546119608391002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 276.1689169331507, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119.54742950303944, tolerance: 0.22271582040500962
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.856045292144472, tolerance: 0.22546119608391002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 276.39677496595027, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119.64779820244996, tolerance: 0.22271582040500962
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3158156588021939, tolerance: 0.22546119608391002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 276.650767436163, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119.7758039404464, tolerance: 0.22271582040500962
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4617900078471848, tolerance: 0.22546119608391002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 276.93257504899276, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119.93175528957102, tolerance: 0.22271582040500962
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.764753233983015, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.775154223689924, tolerance: 0.22271582040500962
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9819895963112231, tolerance: 0.22401174265042684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BENAVEN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8086445291621658, tolerance: 0.22271582040500962
#   model = cd_fast.enet_coordinate_descent(

# %%
svr = SVR(kernel = 'linear');
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,svr,{'C' : range(1,5),
                                       'epsilon' : np.linspace(0.1,1,10)})

# %%
svr = SVR();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test,svr,{'C' : range(1,5),
                                        'epsilon' : np.linspace(0.1,1,10), 
                                       'kernel' : ['rbf','poly','sigmoid']})

# %%
rfr = RandomForestRegressor();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test, rfr, {'min_samples_split' : [2, 5, 10], 
                                             'min_samples_leaf' : [1, 2, 4], 
                                             'max_depth': range(5,16,1)})

# %%
gb = LGBMRegressor();
recap_table_log(X_train,Y_energy_log_train,Y_ghg_log_train,X_test,Y_energy_log_test,Y_ghg_log_test, gb, {'n_estimators': [150],'max_depth':range(5,16), 
                                                                                                     'learning_rate' : [0.0001,0.001,0.01,0.1,1], 
                                                                                                     'boosting_type' : ['gbdt','goss', 'dart'], 'num_leaves':[30]})

# %%
recap_energy_log
# Out:
#                                   R²         RMSE Prediction time  \
# Model for energy log
# LinearRegression()      -6.34915e+20  1.02892e+18           0.002
# Ridge()                 -1.86857e+21  1.76513e+18           0.002
# Lasso()                  -5.3921e+21  2.99848e+18        0.002002
# SVR(kernel='linear')    -1.03493e+30   4.1541e+22        0.034001
# SVR()                        0.12836  3.81232e+07        0.070004
# RandomForestRegressor()      0.32197  3.36238e+07        0.041762
# LGBMRegressor()               0.3448  3.30528e+07        0.026003
#
#                                                            Best parameters
# Model for energy log
# LinearRegression()                                                      {}
# Ridge()                                                {'alpha': 2.656088}
# Lasso()                                                {'alpha': 0.002848}
# SVR(kernel='linear')                              {'C': 2, 'epsilon': 0.5}
# SVR()                            {'C': 3, 'epsilon': 0.2, 'kernel': 'rbf'}
# RandomForestRegressor()  {'max_depth': 10, 'min_samples_leaf': 1, 'min_...
# LGBMRegressor()          {'boosting_type': 'gbdt', 'learning_rate': 0.1...

# %%
recap_ghg_log
# Out:
#                                   R²         RMSE Prediction time  \
# Model for GHG log
# LinearRegression()      -8.62632e+20  2.24678e+13        0.002999
# Ridge()                 -3.86224e+21  4.75408e+13        0.001998
# Lasso()                 -5.72517e+21  5.78817e+13        0.002001
# SVR(kernel='linear')    -9.02752e+31  7.26828e+18        0.048004
# SVR()                        0.16728      698.067        0.055002
# RandomForestRegressor()      0.50128      540.226        0.033005
# LGBMRegressor()              0.60391      481.443        0.013001
#
#                                                            Best parameters
# Model for GHG log
# LinearRegression()                                                      {}
# Ridge()                                                {'alpha': 4.641589}
# Lasso()                                                {'alpha': 0.002154}
# SVR(kernel='linear')                              {'C': 1, 'epsilon': 0.2}
# SVR()                            {'C': 3, 'epsilon': 0.6, 'kernel': 'rbf'}
# RandomForestRegressor()  {'max_depth': 15, 'min_samples_leaf': 4, 'min_...
# LGBMRegressor()          {'boosting_type': 'gbdt', 'learning_rate': 0.1...

# %%
recap_energy_log.iloc[-1,-1]
# Out:
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
